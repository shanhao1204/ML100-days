# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',None)

# %%
path='/Users/syuan/Downloads/2021-ml100marathon-midterm'
data_path=os.path.join(path,'train_data.csv')
data_path2=os.path.join(path,'test_features.csv')
df_train=pd.read_csv(data_path)
df_test=pd.read_csv(data_path2)
# train_y=df_train['poi']
# num_train=train_y.shape[0]
# df_train.drop('poi',inplace=True,axis=1)
# df=df_train.append(df_test)
# df.reset_index(drop=True,inplace=True)

# %%
col_bool=df_train.columns.isin(df_train.select_dtypes(include='float64').columns)
df_train[df_train.columns[col_bool]].fillna(df_train.mean()).corr()
# Out:
#                                   bonus  deferral_payments  deferred_income  \
# bonus                      1.000000e+00           0.103813        -0.191883
# deferral_payments          1.038128e-01           1.000000        -0.371580
# deferred_income           -1.918826e-01          -0.371580         1.000000
# director_fees              9.399480e-30           0.099596         0.012579
# exercised_stock_options    4.777801e-01          -0.127531        -0.211034
# expenses                   2.165139e-02          -0.099371         0.079193
# from_messages              5.682897e-02           0.074443        -0.056909
# from_poi_to_this_person    5.394113e-01          -0.002694         0.014736
# from_this_person_to_poi    3.460736e-01           0.042417        -0.012344
# loan_advances              4.063433e-01          -0.068254         0.024718
# long_term_incentive        4.368111e-01          -0.087571        -0.105815
# ...

# %%
abs(df_train.corr()['poi']).sort_values()
# Out:
# to_messages                  0.023047
# from_this_person_to_poi      0.096864
# shared_receipt_with_poi      0.120467
# from_messages                0.126760
# from_poi_to_this_person      0.127932
# expenses                     0.136386
# deferred_income              0.224654
# other                        0.225619
# long_term_incentive          0.227805
# bonus                        0.242170
# deferral_payments            0.251548
# restricted_stock             0.261102
# total_payments               0.271335
# salary                       0.371917
# total_stock_value            0.443098
# exercised_stock_options      0.591972
# poi                          1.000000
# loan_advances                1.000000
# director_fees                     NaN
# restricted_stock_deferred         NaN
# Name: poi, dtype: float64

# %%
print(len(df))
na=df.isnull().sum(axis=1).nlargest(20)
df.iloc[na.index]
# Out:
# 146
#                               name  bonus  deferral_payments  deferred_income  \
# 107              LOCKHART EUGENE E    NaN                NaN              NaN
# 17                    WROBEL BRUCE    NaN                NaN              NaN
# 30                  WHALEY DAVID A    NaN                NaN              NaN
# 65   THE TRAVEL AGENCY IN THE PARK    NaN                NaN              NaN
# 79                   GRAMM WENDY L    NaN                NaN              NaN
# 62               SCRIMSHAW MATTHEW    NaN                NaN              NaN
# 70                     GILLIS JOHN    NaN                NaN              NaN
# 94                 CLINE KENNETH W    NaN                NaN              NaN
# 98                    SAVAGE FRANK    NaN                NaN        -121284.0
# 100                   WAKEHAM JOHN    NaN                NaN              NaN
# 136                  WODRASKA JOHN    NaN                NaN              NaN
# ...

# %%
df
# Out:
#                      name      bonus  deferral_payments  deferred_income  \
# 0          RICE KENNETH D  1750000.0                NaN       -3504386.0
# 1      SKILLING JEFFREY K  5600000.0                NaN              NaN
# 2              SHELBY REX   200000.0                NaN          -4167.0
# 3        KOPPER MICHAEL J   800000.0                NaN              NaN
# 4    CALGER CHRISTOPHER F  1250000.0                NaN        -262500.0
# ..                    ...        ...                ...              ...
# 141       BIBI PHILIPPE A  1000000.0                NaN              NaN
# 142       SHERRIFF JOHN R  1500000.0                NaN              NaN
# 143          GIBBS DANA R        NaN           504610.0              NaN
# 144        LINDHOLM TOD A   200000.0           204075.0              NaN
# 145       MCMAHON JEFFREY  2600000.0                NaN              NaN
#
#      director_fees                 email_address  exercised_stock_options  \
# ...
