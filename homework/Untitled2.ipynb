# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(200,3),columns=['A','B','C'],index=pd.date_range('1/1/2020',periods=200))
df=df.cumsum()
df.plot()
# Out:
# <AxesSubplot:>

# %%
df=pd.Series(np.random.randn(4),index=['A','B','C','D'],name='title')
df.plot.pie()
# Out:
# <AxesSubplot:ylabel='title'>

# %%
df=pd.DataFrame(np.random.rand(10,2),columns=['A','B'])
df.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>
